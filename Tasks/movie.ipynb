# %%
# Function to create a video with text overlay
def create_video_with_text():
    from moviepy.editor import VideoFileClip, TextClip, CompositeVideoClip

    video = VideoFileClip("car.mp4").subclip(3, 4)

    # Make the text. Many more options are available.
    txt_clip = (TextClip("Video Editing AI", fontsize=70, color='white')
                .set_position('center')
                .set_duration(10))

    result = CompositeVideoClip([video, txt_clip])  # Overlay text on video
    result.write_videofile("edited.webm", fps=25)

# %%
create_video_with_text()
# Out:
# Moviepy - Building video edited.webm.
# MoviePy - Writing audio in editedTEMP_MPY_wvf_snd.ogg
# MoviePy - Done.
# Moviepy - Writing video edited.webm
# Moviepy - Done !
# Moviepy - video ready edited.webm

# %%
# function to create clip extractor

def create_clip_extractor():
    from moviepy.editor import VideoFileClip

    video = VideoFileClip("car.mp4")
    clip = video.subclip(3, 4)
    clip.write_videofile("clip.mp4")


create_clip_extractor()
# Out:
# Moviepy - Building video clip.mp4.
# MoviePy - Writing audio in clipTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video clip.mp4
# Moviepy - Done !
# Moviepy - video ready clip.mp4

# %%
# function to create video compression

def create_video_compression():
    from moviepy.editor import VideoFileClip

    video = VideoFileClip("car.mp4")
    video = video.subclip(3, 4)
    video = video.without_audio()
    video = video.resize(0.5)
    video = video.set_fps(30)
    video.write_videofile("compressed.mp4")
    
create_video_compression()
# Out:
# Moviepy - Building video compressed.mp4.
# Moviepy - Writing video compressed.mp4
# Moviepy - Done !
# Moviepy - video ready compressed.mp4

# %%
# function to create speed adjustment of video


def create_speed_adjustment():
    from moviepy.editor import VideoFileClip, concatenate
    video = VideoFileClip("car.mp4")
    video = video.subclip(3, 4)
    video = video.speedx(0.5)
    video.write_videofile("speed.mp4")

def create_high_low_speed():
    from moviepy.editor import VideoFileClip, concatenate
    video = VideoFileClip("car.mp4")
    video_high_speed = video.subclip(3, 4).speedx(2)  # High speed segment
    video_low_speed = video.subclip(4, 5).speedx(0.5)  # Low speed segment

    final_video = concatenate([video_high_speed, video_low_speed])
    final_video.write_videofile("high_low_speed.mp4")

create_high_low_speed()
    
create_speed_adjustment()
# Out:
# Moviepy - Building video high_low_speed.mp4.
# MoviePy - Writing audio in high_low_speedTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video high_low_speed.mp4
# Moviepy - Done !
# Moviepy - video ready high_low_speed.mp4
# Moviepy - Building video speed.mp4.
# MoviePy - Writing audio in speedTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video speed.mp4
# Moviepy - Done !
# Moviepy - video ready speed.mp4

# %%
# background removal

# %%
# object detection

# %%
# background removal

def create_video_background_removal():
    import cv2
    from moviepy.editor import VideoFileClip
    video = VideoFileClip("car.mp4")
    
    def remove_background(frame):
        bgr_frame = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
        gray_frame = cv2.cvtColor(bgr_frame, cv2.COLOR_BGR2GRAY)
        _, mask = cv2.threshold(gray_frame, 100, 255, cv2.THRESH_BINARY_INV)
        masked_frame = cv2.bitwise_and(bgr_frame, bgr_frame, mask=mask)
        return cv2.cvtColor(masked_frame, cv2.COLOR_BGR2RGB)
    
    modified_video = video.fl_image(remove_background)
    modified_video.write_videofile("remove_background.mp4", codec="libx264", audio_codec="aac", fps=video.fps)

create_video_background_removal()
# Out:
# Moviepy - Building video remove_background.mp4.
# MoviePy - Writing audio in remove_backgroundTEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video remove_background.mp4
# Moviepy - Done !
# Moviepy - video ready remove_background.mp4

# %%
from ultralytics import YOLO
from ultralytics.utils.plotting import Annotator, colors
import cv2

model = YOLO("yolov8n.pt")
names = model.names

cap = cv2.VideoCapture(r"C:\Users\gaura\Desktop\Vool2024\Vool\comvision\car.mp4")
assert cap.isOpened(), "Error reading video file"
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

# Blur ratio
blur_ratio = 50

# Video writer
video_writer = cv2.VideoWriter("object_blurring_output.avi",
                               cv2.VideoWriter_fourcc(*'mp4v'),
                               fps, (w, h))

while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("Video frame is empty or video processing has been successfully completed.")
        break

    results = model.predict(im0, show=False)
    boxes = results[0].boxes.xyxy.cpu().tolist()
    clss = results[0].boxes.cls.cpu().tolist()
    annotator = Annotator(im0, line_width=2, example=names)

    if boxes is not None:
        for box, cls in zip(boxes, clss):
            annotator.box_label(box, color=colors(int(cls), True), label=names[int(cls)])

            obj = im0[int(box[1]):int(box[3]), int(box[0]):int(box[2])]
            blur_obj = cv2.blur(obj, (blur_ratio, blur_ratio))

            im0[int(box[1]):int(box[3]), int(box[0]):int(box[2])] = blur_obj

    cv2.imshow("ultralytics", im0)
    video_writer.write(im0)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
video_writer.release()
cv2.destroyAllWindows()
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.1.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 21.0MB/s]
# 0: 384x640 1 car, 1 airplane, 218.1ms
# Speed: 8.6ms preprocess, 218.1ms inference, 10.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 133.3ms
# Speed: 12.8ms preprocess, 133.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 119.8ms
# Speed: 5.0ms preprocess, 119.8ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 122.7ms
# Speed: 0.0ms preprocess, 122.7ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 99.2ms
# Speed: 0.0ms preprocess, 99.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 116.7ms
# Speed: 0.0ms preprocess, 116.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 traffic light, 120.8ms
# Speed: 0.0ms preprocess, 120.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 101.1ms
# Speed: 2.5ms preprocess, 101.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 119.5ms
# Speed: 0.0ms preprocess, 119.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trucks, 140.2ms
# Speed: 0.0ms preprocess, 140.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 131.7ms
# Speed: 8.0ms preprocess, 131.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trucks, 130.9ms
# Speed: 0.0ms preprocess, 130.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trucks, 125.0ms
# Speed: 3.9ms preprocess, 125.0ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 129.1ms
# Speed: 4.0ms preprocess, 129.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 109.0ms
# Speed: 3.0ms preprocess, 109.0ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 101.5ms
# Speed: 8.0ms preprocess, 101.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 178.8ms
# Speed: 11.8ms preprocess, 178.8ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 108.1ms
# Speed: 2.2ms preprocess, 108.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 109.1ms
# Speed: 0.0ms preprocess, 109.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 98.3ms
# Speed: 6.9ms preprocess, 98.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 103.4ms
# Speed: 0.0ms preprocess, 103.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 98.2ms
# Speed: 0.0ms preprocess, 98.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 88.2ms
# Speed: 0.0ms preprocess, 88.2ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 98.6ms
# Speed: 6.1ms preprocess, 98.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 123.4ms
# Speed: 5.0ms preprocess, 123.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 122.2ms
# Speed: 2.2ms preprocess, 122.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 126.0ms
# Speed: 3.3ms preprocess, 126.0ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 143.4ms
# Speed: 0.0ms preprocess, 143.4ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 132.8ms
# Speed: 3.6ms preprocess, 132.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 122.6ms
# Speed: 0.0ms preprocess, 122.6ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 126.4ms
# Speed: 0.0ms preprocess, 126.4ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 135.6ms
# Speed: 0.0ms preprocess, 135.6ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 123.0ms
# Speed: 4.5ms preprocess, 123.0ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 263.1ms
# Speed: 0.0ms preprocess, 263.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 117.4ms
# Speed: 8.8ms preprocess, 117.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 truck, 121.7ms
# Speed: 0.0ms preprocess, 121.7ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 129.2ms
# Speed: 0.0ms preprocess, 129.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 126.3ms
# Speed: 8.1ms preprocess, 126.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trucks, 132.4ms
# Speed: 4.7ms preprocess, 132.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 116.9ms
# Speed: 0.0ms preprocess, 116.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 102.6ms
# Speed: 0.0ms preprocess, 102.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 105.8ms
# Speed: 0.0ms preprocess, 105.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 99.5ms
# Speed: 0.0ms preprocess, 99.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 88.7ms
# Speed: 0.0ms preprocess, 88.7ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 90.7ms
# Speed: 0.0ms preprocess, 90.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 89.7ms
# Speed: 0.0ms preprocess, 89.7ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 107.6ms
# Speed: 0.0ms preprocess, 107.6ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 100.1ms
# Speed: 8.0ms preprocess, 100.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 97.4ms
# Speed: 7.0ms preprocess, 97.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 107.4ms
# Speed: 11.1ms preprocess, 107.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 95.0ms
# Speed: 0.0ms preprocess, 95.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 88.9ms
# Speed: 0.0ms preprocess, 88.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 83.8ms
# Speed: 3.4ms preprocess, 83.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 85.9ms
# Speed: 5.0ms preprocess, 85.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 95.0ms
# Speed: 2.0ms preprocess, 95.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 104.4ms
# Speed: 0.0ms preprocess, 104.4ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 97.5ms
# Speed: 0.0ms preprocess, 97.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 128.7ms
# Speed: 1.4ms preprocess, 128.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 1 truck, 89.6ms
# Speed: 7.0ms preprocess, 89.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 truck, 102.1ms
# Speed: 0.0ms preprocess, 102.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 93.8ms
# Speed: 6.0ms preprocess, 93.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 train, 97.2ms
# Speed: 0.0ms preprocess, 97.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 101.6ms
# Speed: 0.0ms preprocess, 101.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 106.9ms
# Speed: 0.0ms preprocess, 106.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 90.1ms
# Speed: 1.6ms preprocess, 90.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 98.8ms
# Speed: 5.5ms preprocess, 98.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 115.1ms
# Speed: 0.0ms preprocess, 115.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 airplanes, 1 suitcase, 109.5ms
# Speed: 1.4ms preprocess, 109.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 116.5ms
# Speed: 0.0ms preprocess, 116.5ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 105.4ms
# Speed: 0.0ms preprocess, 105.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 104.9ms
# Speed: 0.0ms preprocess, 104.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 108.0ms
# Speed: 0.0ms preprocess, 108.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 81.7ms
# Speed: 0.0ms preprocess, 81.7ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 90.3ms
# Speed: 2.0ms preprocess, 90.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 92.1ms
# Speed: 0.0ms preprocess, 92.1ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 airplane, 102.0ms
# Speed: 2.5ms preprocess, 102.0ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 99.4ms
# Speed: 0.0ms preprocess, 99.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 95.0ms
# Speed: 4.9ms preprocess, 95.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 100.2ms
# Speed: 1.0ms preprocess, 100.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 84.7ms
# Speed: 3.5ms preprocess, 84.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 86.7ms
# Speed: 3.5ms preprocess, 86.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 83.2ms
# Speed: 1.8ms preprocess, 83.2ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 161.3ms
# Speed: 1.5ms preprocess, 161.3ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 train, 213.3ms
# Speed: 8.4ms preprocess, 213.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 233.0ms
# Speed: 6.1ms preprocess, 233.0ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 239.9ms
# Speed: 2.1ms preprocess, 239.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 230.7ms
# Speed: 7.4ms preprocess, 230.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 250.7ms
# Speed: 9.3ms preprocess, 250.7ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 217.6ms
# Speed: 7.1ms preprocess, 217.6ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 230.1ms
# Speed: 0.8ms preprocess, 230.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 237.4ms
# Speed: 0.0ms preprocess, 237.4ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 train, 229.4ms
# Speed: 5.2ms preprocess, 229.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 216.6ms
# Speed: 1.6ms preprocess, 216.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 218.8ms
# Speed: 8.3ms preprocess, 218.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 224.5ms
# Speed: 3.8ms preprocess, 224.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 228.6ms
# Speed: 6.7ms preprocess, 228.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 237.1ms
# Speed: 0.4ms preprocess, 237.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 244.3ms
# Speed: 0.0ms preprocess, 244.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 247.8ms
# Speed: 1.1ms preprocess, 247.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 230.5ms
# Speed: 2.4ms preprocess, 230.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 1 truck, 226.0ms
# Speed: 5.1ms preprocess, 226.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 232.0ms
# Speed: 0.3ms preprocess, 232.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 227.5ms
# Speed: 2.1ms preprocess, 227.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 227.6ms
# Speed: 6.3ms preprocess, 227.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 249.4ms
# Speed: 0.0ms preprocess, 249.4ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 211.7ms
# Speed: 3.5ms preprocess, 211.7ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 220.9ms
# Speed: 2.3ms preprocess, 220.9ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 225.5ms
# Speed: 2.9ms preprocess, 225.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 1 truck, 218.5ms
# Speed: 3.6ms preprocess, 218.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 trains, 1 truck, 221.9ms
# Speed: 2.5ms preprocess, 221.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 1 truck, 209.1ms
# Speed: 3.3ms preprocess, 209.1ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 2 trucks, 223.2ms
# Speed: 5.7ms preprocess, 223.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 1 truck, 251.5ms
# Speed: 1.6ms preprocess, 251.5ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 217.1ms
# Speed: 2.3ms preprocess, 217.1ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 217.5ms
# Speed: 4.0ms preprocess, 217.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 234.0ms
# Speed: 3.0ms preprocess, 234.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trains, 237.6ms
# Speed: 5.0ms preprocess, 237.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 train, 1 traffic light, 323.5ms
# Speed: 1.0ms preprocess, 323.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 airplane, 1 train, 225.6ms
# Speed: 2.6ms preprocess, 225.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 train, 1 truck, 227.7ms
# Speed: 6.5ms preprocess, 227.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 train, 226.1ms
# Speed: 8.8ms preprocess, 226.1ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 train, 220.0ms
# Speed: 4.0ms preprocess, 220.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 203.9ms
# Speed: 3.1ms preprocess, 203.9ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 249.7ms
# Speed: 0.0ms preprocess, 249.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 232.6ms
# Speed: 1.7ms preprocess, 232.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 239.3ms
# Speed: 0.0ms preprocess, 239.3ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 216.4ms
# Speed: 3.1ms preprocess, 216.4ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 train, 229.3ms
# Speed: 3.5ms preprocess, 229.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 232.5ms
# Speed: 1.7ms preprocess, 232.5ms inference, 14.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 226.2ms
# Speed: 10.7ms preprocess, 226.2ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 250.1ms
# Speed: 6.2ms preprocess, 250.1ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 246.1ms
# Speed: 5.4ms preprocess, 246.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 truck, 237.4ms
# Speed: 0.0ms preprocess, 237.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trucks, 209.2ms
# Speed: 9.9ms preprocess, 209.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 222.2ms
# Speed: 13.0ms preprocess, 222.2ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 223.0ms
# Speed: 6.4ms preprocess, 223.0ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 214.5ms
# Speed: 2.5ms preprocess, 214.5ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 231.1ms
# Speed: 3.3ms preprocess, 231.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 223.4ms
# Speed: 1.9ms preprocess, 223.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 214.9ms
# Speed: 2.1ms preprocess, 214.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 218.4ms
# Speed: 3.2ms preprocess, 218.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 227.8ms
# Speed: 6.2ms preprocess, 227.8ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 224.5ms
# Speed: 5.7ms preprocess, 224.5ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 230.2ms
# Speed: 2.4ms preprocess, 230.2ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 airplanes, 217.5ms
# Speed: 10.3ms preprocess, 217.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 200.8ms
# Speed: 10.6ms preprocess, 200.8ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 215.0ms
# Speed: 9.4ms preprocess, 215.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 223.9ms
# Speed: 2.0ms preprocess, 223.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 231.3ms
# Speed: 13.4ms preprocess, 231.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 228.5ms
# Speed: 4.1ms preprocess, 228.5ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 223.2ms
# Speed: 1.7ms preprocess, 223.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 220.9ms
# Speed: 8.0ms preprocess, 220.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 208.1ms
# Speed: 2.8ms preprocess, 208.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 226.9ms
# Speed: 2.2ms preprocess, 226.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 212.8ms
# Speed: 2.0ms preprocess, 212.8ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 chair, 209.7ms
# Speed: 8.7ms preprocess, 209.7ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 traffic light, 192.7ms
# Speed: 5.0ms preprocess, 192.7ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 traffic light, 229.1ms
# Speed: 1.6ms preprocess, 229.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 236.6ms
# Speed: 3.7ms preprocess, 236.6ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 224.6ms
# Speed: 0.9ms preprocess, 224.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 truck, 402.8ms
# Speed: 7.7ms preprocess, 402.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 airplane, 217.7ms
# Speed: 2.1ms preprocess, 217.7ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 236.4ms
# Speed: 0.0ms preprocess, 236.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 221.9ms
# Speed: 5.1ms preprocess, 221.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 213.0ms
# Speed: 0.5ms preprocess, 213.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 221.5ms
# Speed: 0.0ms preprocess, 221.5ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 211.5ms
# Speed: 2.6ms preprocess, 211.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 217.4ms
# Speed: 3.2ms preprocess, 217.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 214.1ms
# Speed: 1.8ms preprocess, 214.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 truck, 1 traffic light, 215.1ms
# Speed: 4.1ms preprocess, 215.1ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 truck, 214.1ms
# Speed: 4.1ms preprocess, 214.1ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 261.3ms
# Speed: 2.5ms preprocess, 261.3ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 211.6ms
# Speed: 7.2ms preprocess, 211.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 308.2ms
# Speed: 8.0ms preprocess, 308.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 262.3ms
# Speed: 1.6ms preprocess, 262.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 208.3ms
# Speed: 4.3ms preprocess, 208.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 224.5ms
# Speed: 2.7ms preprocess, 224.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 236.8ms
# Speed: 2.7ms preprocess, 236.8ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 259.8ms
# Speed: 5.1ms preprocess, 259.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 197.9ms
# Speed: 2.6ms preprocess, 197.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 217.2ms
# Speed: 3.2ms preprocess, 217.2ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 206.8ms
# Speed: 0.9ms preprocess, 206.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 323.7ms
# Speed: 5.0ms preprocess, 323.7ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 246.6ms
# Speed: 2.6ms preprocess, 246.6ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 226.8ms
# Speed: 3.2ms preprocess, 226.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 348.8ms
# Speed: 2.4ms preprocess, 348.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 244.8ms
# Speed: 4.3ms preprocess, 244.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 244.1ms
# Speed: 1.5ms preprocess, 244.1ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 318.7ms
# Speed: 4.9ms preprocess, 318.7ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 277.2ms
# Speed: 2.7ms preprocess, 277.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 251.1ms
# Speed: 5.4ms preprocess, 251.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 239.1ms
# Speed: 6.9ms preprocess, 239.1ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
# Video frame is empty or video processing has been successfully completed.

# %%
import cv2
import mediapipe as mp
import numpy as np

mp_selfie_segmentation = mp.solutions.selfie_segmentation

# Load the video file
VIDEO_FILE = "car.mp4"

# Output video file name
OUTPUT_FILE = "outputcar.mp4"

# Background color
BG_COLOR = (192, 192, 192) # gray

# Create a video capture object
cap = cv2.VideoCapture(VIDEO_FILE)

# Get video properties
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Define the codec and create VideoWriter object
out = cv2.VideoWriter(OUTPUT_FILE, cv2.VideoWriter_fourcc(*'mp4v'), fps, (frame_width, frame_height))

# Initialize MediaPipe Selfie Segmentation
with mp_selfie_segmentation.SelfieSegmentation(model_selection=1) as selfie_segmentation:
    while cap.isOpened():
        # Read a frame from the video
        ret, frame = cap.read()
        if not ret:
            break
        
        # Convert the frame from BGR to RGB
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        
        # Process the frame for selfie segmentation
        results = selfie_segmentation.process(frame_rgb)
        
        # Extract the segmentation mask
        segmentation_mask = results.segmentation_mask
        
        # Create a condition for the segmentation mask
        condition = np.stack((segmentation_mask,) * 3, axis=-1) > 0.1
        
        # Create a background image
        bg_image = np.zeros(frame.shape, dtype=np.uint8)
        bg_image[:] = BG_COLOR
        
        # Replace the background with the input frame based on the segmentation mask
        output_frame = np.where(condition, frame, bg_image)
        
        # Write the output frame to the output video
        out.write(output_frame)

        # Display the output frame
        cv2.imshow('Output Video', output_frame)
        
        # Check for the 'q' key to quit
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

# Release resources
cap.release()
out.release()
cv2.destroyAllWindows()

# %%
import cv2
from ultralytics import YOLO
from ultralytics.utils.plotting import colors, Annotator

model = YOLO("yolov8n.pt")
names = model.model.names
cap = cv2.VideoCapture("car.mp4")
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

out = cv2.VideoWriter('visioneye-pinpoint.avi', cv2.VideoWriter_fourcc(*'MJPG'), fps, (w, h))

center_point = (-10, h)

while True:
    ret, im0 = cap.read()
    if not ret:
        print("Video frame is empty or video processing has been successfully completed.")
        break

    results = model.predict(im0)
    boxes = results[0].boxes.xyxy.cpu()
    clss = results[0].boxes.cls.cpu().tolist()

    annotator = Annotator(im0, line_width=2)

    for box, cls in zip(boxes, clss):
        annotator.box_label(box, label=names[int(cls)], color=colors(int(cls)))
        annotator.visioneye(box, center_point)

    out.write(im0)
    cv2.imshow("visioneye-pinpoint", im0)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

out.release()
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 car, 1 airplane, 284.0ms
# Speed: 0.0ms preprocess, 284.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 144.7ms
# Speed: 0.0ms preprocess, 144.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 130.1ms
# Speed: 0.0ms preprocess, 130.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 133.4ms
# Speed: 7.2ms preprocess, 133.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 244.8ms
# Speed: 3.5ms preprocess, 244.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 149.9ms
# Speed: 0.0ms preprocess, 149.9ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 traffic light, 164.3ms
# Speed: 0.0ms preprocess, 164.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 117.7ms
# Speed: 8.2ms preprocess, 117.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 110.6ms
# Speed: 0.0ms preprocess, 110.6ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trucks, 123.1ms
# Speed: 0.0ms preprocess, 123.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 113.2ms
# Speed: 0.0ms preprocess, 113.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trucks, 110.8ms
# Speed: 3.1ms preprocess, 110.8ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trucks, 122.9ms
# Speed: 0.0ms preprocess, 122.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 107.2ms
# Speed: 3.4ms preprocess, 107.2ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 103.4ms
# Speed: 2.3ms preprocess, 103.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 89.4ms
# Speed: 0.0ms preprocess, 89.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 97.4ms
# Speed: 0.0ms preprocess, 97.4ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 115.1ms
# Speed: 0.0ms preprocess, 115.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 95.9ms
# Speed: 0.0ms preprocess, 95.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 89.1ms
# Speed: 0.0ms preprocess, 89.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 91.3ms
# Speed: 0.0ms preprocess, 91.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 104.3ms
# Speed: 0.0ms preprocess, 104.3ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 97.2ms
# Speed: 0.0ms preprocess, 97.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 98.7ms
# Speed: 6.1ms preprocess, 98.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 80.0ms
# Speed: 0.5ms preprocess, 80.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 82.6ms
# Speed: 4.2ms preprocess, 82.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 99.3ms
# Speed: 1.5ms preprocess, 99.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 104.9ms
# Speed: 0.0ms preprocess, 104.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 86.3ms
# Speed: 0.5ms preprocess, 86.3ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 94.5ms
# Speed: 0.0ms preprocess, 94.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 100.0ms
# Speed: 0.8ms preprocess, 100.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 105.6ms
# Speed: 0.0ms preprocess, 105.6ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 97.2ms
# Speed: 0.0ms preprocess, 97.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 97.5ms
# Speed: 0.0ms preprocess, 97.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 90.9ms
# Speed: 0.0ms preprocess, 90.9ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 truck, 90.4ms
# Speed: 8.4ms preprocess, 90.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 99.9ms
# Speed: 5.6ms preprocess, 99.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 97.9ms
# Speed: 0.0ms preprocess, 97.9ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trucks, 106.3ms
# Speed: 0.0ms preprocess, 106.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 89.4ms
# Speed: 0.0ms preprocess, 89.4ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 92.3ms
# Speed: 7.6ms preprocess, 92.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 82.6ms
# Speed: 4.2ms preprocess, 82.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 92.1ms
# Speed: 5.3ms preprocess, 92.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 98.7ms
# Speed: 4.9ms preprocess, 98.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 123.2ms
# Speed: 0.0ms preprocess, 123.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 107.4ms
# Speed: 0.9ms preprocess, 107.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 113.6ms
# Speed: 0.0ms preprocess, 113.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 105.7ms
# Speed: 8.4ms preprocess, 105.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 107.6ms
# Speed: 4.5ms preprocess, 107.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 104.9ms
# Speed: 2.3ms preprocess, 104.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 89.7ms
# Speed: 0.0ms preprocess, 89.7ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 98.2ms
# Speed: 0.0ms preprocess, 98.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 115.2ms
# Speed: 1.5ms preprocess, 115.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 117.7ms
# Speed: 1.4ms preprocess, 117.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 102.3ms
# Speed: 3.0ms preprocess, 102.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 117.5ms
# Speed: 1.6ms preprocess, 117.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 124.4ms
# Speed: 6.8ms preprocess, 124.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 116.4ms
# Speed: 0.0ms preprocess, 116.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 1 truck, 111.5ms
# Speed: 4.7ms preprocess, 111.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 truck, 101.1ms
# Speed: 4.4ms preprocess, 101.1ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 98.2ms
# Speed: 1.7ms preprocess, 98.2ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 train, 96.6ms
# Speed: 0.0ms preprocess, 96.6ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 106.1ms
# Speed: 0.0ms preprocess, 106.1ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 97.4ms
# Speed: 8.7ms preprocess, 97.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 102.4ms
# Speed: 0.0ms preprocess, 102.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 98.9ms
# Speed: 0.0ms preprocess, 98.9ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 115.7ms
# Speed: 0.0ms preprocess, 115.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 airplanes, 1 suitcase, 116.5ms
# Speed: 6.2ms preprocess, 116.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 99.2ms
# Speed: 0.0ms preprocess, 99.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 94.0ms
# Speed: 0.0ms preprocess, 94.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 119.9ms
# Speed: 3.6ms preprocess, 119.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 100.2ms
# Speed: 0.0ms preprocess, 100.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 112.3ms
# Speed: 0.0ms preprocess, 112.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 97.3ms
# Speed: 0.6ms preprocess, 97.3ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 92.6ms
# Speed: 6.1ms preprocess, 92.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 airplane, 116.8ms
# Speed: 0.0ms preprocess, 116.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 98.4ms
# Speed: 3.1ms preprocess, 98.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 106.2ms
# Speed: 6.1ms preprocess, 106.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 108.6ms
# Speed: 4.9ms preprocess, 108.6ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 107.0ms
# Speed: 0.6ms preprocess, 107.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 97.0ms
# Speed: 0.0ms preprocess, 97.0ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 102.3ms
# Speed: 3.0ms preprocess, 102.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 88.8ms
# Speed: 8.4ms preprocess, 88.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 train, 88.1ms
# Speed: 0.0ms preprocess, 88.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 104.9ms
# Speed: 0.0ms preprocess, 104.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 89.9ms
# Speed: 6.8ms preprocess, 89.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 88.4ms
# Speed: 0.0ms preprocess, 88.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 107.8ms
# Speed: 2.5ms preprocess, 107.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 112.8ms
# Speed: 0.0ms preprocess, 112.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 89.9ms
# Speed: 0.0ms preprocess, 89.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 98.0ms
# Speed: 0.0ms preprocess, 98.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 train, 93.6ms
# Speed: 5.4ms preprocess, 93.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 89.3ms
# Speed: 0.0ms preprocess, 89.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 93.8ms
# Speed: 4.5ms preprocess, 93.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 92.0ms
# Speed: 0.0ms preprocess, 92.0ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 102.1ms
# Speed: 4.2ms preprocess, 102.1ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 82.4ms
# Speed: 5.1ms preprocess, 82.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 105.5ms
# Speed: 6.3ms preprocess, 105.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 99.9ms
# Speed: 0.0ms preprocess, 99.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 100.6ms
# Speed: 5.8ms preprocess, 100.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 1 truck, 86.7ms
# Speed: 1.4ms preprocess, 86.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 83.7ms
# Speed: 4.8ms preprocess, 83.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 95.2ms
# Speed: 2.1ms preprocess, 95.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 81.0ms
# Speed: 1.8ms preprocess, 81.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 93.9ms
# Speed: 0.0ms preprocess, 93.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 86.0ms
# Speed: 1.4ms preprocess, 86.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 92.2ms
# Speed: 6.0ms preprocess, 92.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 87.8ms
# Speed: 0.0ms preprocess, 87.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 1 truck, 88.5ms
# Speed: 0.0ms preprocess, 88.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 trains, 1 truck, 93.8ms
# Speed: 0.0ms preprocess, 93.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 1 truck, 99.5ms
# Speed: 7.7ms preprocess, 99.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 2 trucks, 108.3ms
# Speed: 1.2ms preprocess, 108.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 1 truck, 98.3ms
# Speed: 0.0ms preprocess, 98.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 97.2ms
# Speed: 0.0ms preprocess, 97.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 92.2ms
# Speed: 0.0ms preprocess, 92.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 97.2ms
# Speed: 1.4ms preprocess, 97.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trains, 99.2ms
# Speed: 0.0ms preprocess, 99.2ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 train, 1 traffic light, 93.4ms
# Speed: 6.5ms preprocess, 93.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 airplane, 1 train, 75.9ms
# Speed: 1.7ms preprocess, 75.9ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 train, 1 truck, 88.4ms
# Speed: 2.6ms preprocess, 88.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 train, 83.6ms
# Speed: 0.0ms preprocess, 83.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 train, 96.6ms
# Speed: 0.0ms preprocess, 96.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 85.8ms
# Speed: 4.1ms preprocess, 85.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 98.2ms
# Speed: 7.7ms preprocess, 98.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 92.1ms
# Speed: 0.0ms preprocess, 92.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 90.0ms
# Speed: 5.2ms preprocess, 90.0ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 88.1ms
# Speed: 2.7ms preprocess, 88.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 train, 94.2ms
# Speed: 1.1ms preprocess, 94.2ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 100.4ms
# Speed: 0.0ms preprocess, 100.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 93.9ms
# Speed: 3.0ms preprocess, 93.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 97.9ms
# Speed: 0.0ms preprocess, 97.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 87.3ms
# Speed: 3.5ms preprocess, 87.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 truck, 113.8ms
# Speed: 0.0ms preprocess, 113.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trucks, 92.2ms
# Speed: 4.8ms preprocess, 92.2ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 80.7ms
# Speed: 8.4ms preprocess, 80.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 151.5ms
# Speed: 5.7ms preprocess, 151.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 127.3ms
# Speed: 3.6ms preprocess, 127.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 108.2ms
# Speed: 0.0ms preprocess, 108.2ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 105.2ms
# Speed: 0.0ms preprocess, 105.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 90.3ms
# Speed: 0.0ms preprocess, 90.3ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 107.6ms
# Speed: 0.0ms preprocess, 107.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 98.8ms
# Speed: 0.0ms preprocess, 98.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 95.6ms
# Speed: 0.0ms preprocess, 95.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 93.7ms
# Speed: 2.5ms preprocess, 93.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 airplanes, 82.9ms
# Speed: 6.0ms preprocess, 82.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 82.2ms
# Speed: 3.0ms preprocess, 82.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 84.3ms
# Speed: 1.3ms preprocess, 84.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 97.4ms
# Speed: 0.0ms preprocess, 97.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 84.9ms
# Speed: 2.3ms preprocess, 84.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 100.4ms
# Speed: 0.0ms preprocess, 100.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 98.5ms
# Speed: 5.2ms preprocess, 98.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 85.7ms
# Speed: 0.0ms preprocess, 85.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 91.2ms
# Speed: 0.0ms preprocess, 91.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 94.8ms
# Speed: 4.7ms preprocess, 94.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 93.0ms
# Speed: 0.0ms preprocess, 93.0ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 chair, 89.9ms
# Speed: 8.5ms preprocess, 89.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 traffic light, 96.2ms
# Speed: 2.4ms preprocess, 96.2ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 traffic light, 112.7ms
# Speed: 0.0ms preprocess, 112.7ms inference, 9.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 131.8ms
# Speed: 0.0ms preprocess, 131.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 116.3ms
# Speed: 5.6ms preprocess, 116.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 truck, 108.1ms
# Speed: 1.0ms preprocess, 108.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 airplane, 104.7ms
# Speed: 8.6ms preprocess, 104.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 99.6ms
# Speed: 0.0ms preprocess, 99.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 98.8ms
# Speed: 3.3ms preprocess, 98.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 97.7ms
# Speed: 0.0ms preprocess, 97.7ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 98.5ms
# Speed: 0.0ms preprocess, 98.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 102.3ms
# Speed: 2.5ms preprocess, 102.3ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 96.8ms
# Speed: 2.2ms preprocess, 96.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 117.3ms
# Speed: 4.9ms preprocess, 117.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 truck, 1 traffic light, 123.3ms
# Speed: 0.0ms preprocess, 123.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 truck, 106.9ms
# Speed: 0.0ms preprocess, 106.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 113.0ms
# Speed: 0.0ms preprocess, 113.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 114.5ms
# Speed: 0.0ms preprocess, 114.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 105.1ms
# Speed: 1.7ms preprocess, 105.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 98.8ms
# Speed: 0.0ms preprocess, 98.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 106.8ms
# Speed: 2.5ms preprocess, 106.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 98.9ms
# Speed: 0.0ms preprocess, 98.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 95.8ms
# Speed: 2.1ms preprocess, 95.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 101.4ms
# Speed: 3.3ms preprocess, 101.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 104.5ms
# Speed: 0.0ms preprocess, 104.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 118.2ms
# Speed: 0.7ms preprocess, 118.2ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 101.9ms
# Speed: 0.7ms preprocess, 101.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 95.7ms
# Speed: 5.0ms preprocess, 95.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 124.2ms
# Speed: 6.2ms preprocess, 124.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 121.1ms
# Speed: 2.5ms preprocess, 121.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 95.3ms
# Speed: 0.3ms preprocess, 95.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 104.9ms
# Speed: 0.0ms preprocess, 104.9ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 106.7ms
# Speed: 0.0ms preprocess, 106.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 106.0ms
# Speed: 0.0ms preprocess, 106.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 115.2ms
# Speed: 5.5ms preprocess, 115.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 101.8ms
# Speed: 8.6ms preprocess, 101.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 99.3ms
# Speed: 0.0ms preprocess, 99.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Video frame is empty or video processing has been successfully completed.

# %%
import cv2
from ultralytics import YOLO
from ultralytics.utils.plotting import colors, Annotator

def process_video(input_video_path, output_video_path, model_path="yolov8n.pt", center_point=(-10, 480)):
    # Load YOLO model
    model = YOLO(model_path)
    names = model.model.names
    
    # Open video capture
    cap = cv2.VideoCapture(input_video_path)
    w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))
    
    # Define video writer
    out = cv2.VideoWriter(output_video_path, cv2.VideoWriter_fourcc(*'MJPG'), fps, (w, h))
    
    while True:
        ret, im0 = cap.read()
        if not ret:
            print("Video frame is empty or video processing has been successfully completed.")
            break

        # Predict using YOLO model
        results = model.predict(im0)
        boxes = results[0].boxes.xyxy.cpu()
        clss = results[0].boxes.cls.cpu().tolist()

        annotator = Annotator(im0, line_width=2)

        for box, cls in zip(boxes, clss):
            annotator.box_label(box, label=names[int(cls)], color=colors(int(cls)))
            annotator.visioneye(box, center_point)

        # Write annotated frame to output video
        out.write(im0)
        cv2.imshow("visioneye-pinpoint", im0)

        # Check for user input to quit
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    # Release resources
    out.release()
    cap.release()
    cv2.destroyAllWindows()

# Example usage:
process_video("car.mp4", "visioneye-pinpoint.avi")
# Out:
# 0: 384x640 1 car, 1 airplane, 118.8ms
# Speed: 0.0ms preprocess, 118.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 163.4ms
# Speed: 1.2ms preprocess, 163.4ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 131.7ms
# Speed: 0.0ms preprocess, 131.7ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 176.7ms
# Speed: 0.0ms preprocess, 176.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 137.0ms
# Speed: 2.6ms preprocess, 137.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 110.2ms
# Speed: 2.0ms preprocess, 110.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 traffic light, 87.8ms
# Speed: 0.0ms preprocess, 87.8ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 96.1ms
# Speed: 0.0ms preprocess, 96.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 121.6ms
# Speed: 3.2ms preprocess, 121.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trucks, 114.6ms
# Speed: 1.1ms preprocess, 114.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 106.2ms
# Speed: 2.4ms preprocess, 106.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trucks, 105.5ms
# Speed: 0.0ms preprocess, 105.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trucks, 102.8ms
# Speed: 4.3ms preprocess, 102.8ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 108.5ms
# Speed: 4.5ms preprocess, 108.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 114.3ms
# Speed: 0.0ms preprocess, 114.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 115.7ms
# Speed: 0.0ms preprocess, 115.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 124.1ms
# Speed: 0.0ms preprocess, 124.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 92.8ms
# Speed: 2.7ms preprocess, 92.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 106.0ms
# Speed: 0.0ms preprocess, 106.0ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 90.6ms
# Speed: 5.3ms preprocess, 90.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 98.9ms
# Speed: 0.0ms preprocess, 98.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 104.1ms
# Speed: 3.4ms preprocess, 104.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 101.4ms
# Speed: 2.5ms preprocess, 101.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 107.5ms
# Speed: 3.3ms preprocess, 107.5ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 98.6ms
# Speed: 1.4ms preprocess, 98.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 110.8ms
# Speed: 0.0ms preprocess, 110.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 94.7ms
# Speed: 0.0ms preprocess, 94.7ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 99.2ms
# Speed: 0.0ms preprocess, 99.2ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 99.6ms
# Speed: 3.6ms preprocess, 99.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 89.7ms
# Speed: 0.0ms preprocess, 89.7ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trucks, 95.8ms
# Speed: 0.0ms preprocess, 95.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 99.9ms
# Speed: 8.3ms preprocess, 99.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 118.4ms
# Speed: 3.8ms preprocess, 118.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 120.0ms
# Speed: 2.0ms preprocess, 120.0ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 108.6ms
# Speed: 1.2ms preprocess, 108.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 1 truck, 93.9ms
# Speed: 7.7ms preprocess, 93.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 116.8ms
# Speed: 5.8ms preprocess, 116.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 115.4ms
# Speed: 0.0ms preprocess, 115.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trucks, 109.2ms
# Speed: 0.0ms preprocess, 109.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 112.5ms
# Speed: 3.2ms preprocess, 112.5ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 96.1ms
# Speed: 9.2ms preprocess, 96.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bus, 114.5ms
# Speed: 0.2ms preprocess, 114.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 100.7ms
# Speed: 0.0ms preprocess, 100.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 106.5ms
# Speed: 0.0ms preprocess, 106.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 101.1ms
# Speed: 5.8ms preprocess, 101.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 104.8ms
# Speed: 0.0ms preprocess, 104.8ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 113.1ms
# Speed: 1.7ms preprocess, 113.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 116.4ms
# Speed: 1.0ms preprocess, 116.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 106.7ms
# Speed: 2.0ms preprocess, 106.7ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 112.3ms
# Speed: 2.5ms preprocess, 112.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 102.6ms
# Speed: 1.9ms preprocess, 102.6ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 95.6ms
# Speed: 4.0ms preprocess, 95.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 97.6ms
# Speed: 4.7ms preprocess, 97.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 104.9ms
# Speed: 6.2ms preprocess, 104.9ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 99.0ms
# Speed: 0.0ms preprocess, 99.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 100.9ms
# Speed: 5.5ms preprocess, 100.9ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 106.6ms
# Speed: 0.0ms preprocess, 106.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 100.0ms
# Speed: 0.0ms preprocess, 100.0ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 1 truck, 113.2ms
# Speed: 0.0ms preprocess, 113.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 truck, 118.6ms
# Speed: 0.8ms preprocess, 118.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 100.9ms
# Speed: 5.5ms preprocess, 100.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 train, 99.6ms
# Speed: 8.1ms preprocess, 99.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 110.9ms
# Speed: 0.0ms preprocess, 110.9ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 119.8ms
# Speed: 1.6ms preprocess, 119.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 107.8ms
# Speed: 4.5ms preprocess, 107.8ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 104.2ms
# Speed: 7.4ms preprocess, 104.2ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 114.0ms
# Speed: 0.0ms preprocess, 114.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 airplanes, 1 suitcase, 101.7ms
# Speed: 3.8ms preprocess, 101.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 107.8ms
# Speed: 0.0ms preprocess, 107.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 124.3ms
# Speed: 0.0ms preprocess, 124.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 108.3ms
# Speed: 0.0ms preprocess, 108.3ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 108.7ms
# Speed: 0.0ms preprocess, 108.7ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 104.8ms
# Speed: 9.9ms preprocess, 104.8ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 102.2ms
# Speed: 0.0ms preprocess, 102.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 100.1ms
# Speed: 0.0ms preprocess, 100.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 airplane, 103.3ms
# Speed: 5.0ms preprocess, 103.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 buss, 108.0ms
# Speed: 5.5ms preprocess, 108.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 114.4ms
# Speed: 0.0ms preprocess, 114.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 104.3ms
# Speed: 0.0ms preprocess, 104.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 115.6ms
# Speed: 3.9ms preprocess, 115.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 114.9ms
# Speed: 3.5ms preprocess, 114.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 99.5ms
# Speed: 0.0ms preprocess, 99.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 106.2ms
# Speed: 0.0ms preprocess, 106.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 train, 115.8ms
# Speed: 2.0ms preprocess, 115.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 106.2ms
# Speed: 5.3ms preprocess, 106.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 110.0ms
# Speed: 0.0ms preprocess, 110.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 103.5ms
# Speed: 7.4ms preprocess, 103.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 102.2ms
# Speed: 5.2ms preprocess, 102.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 97.6ms
# Speed: 0.0ms preprocess, 97.6ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 106.8ms
# Speed: 0.0ms preprocess, 106.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 100.7ms
# Speed: 0.0ms preprocess, 100.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 train, 114.4ms
# Speed: 0.0ms preprocess, 114.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 97.8ms
# Speed: 0.0ms preprocess, 97.8ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 113.8ms
# Speed: 0.9ms preprocess, 113.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 96.7ms
# Speed: 9.6ms preprocess, 96.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 98.3ms
# Speed: 0.0ms preprocess, 98.3ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 90.9ms
# Speed: 8.2ms preprocess, 90.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 97.0ms
# Speed: 7.1ms preprocess, 97.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 99.5ms
# Speed: 2.1ms preprocess, 99.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 114.3ms
# Speed: 0.0ms preprocess, 114.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 1 truck, 91.5ms
# Speed: 1.4ms preprocess, 91.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 111.0ms
# Speed: 0.0ms preprocess, 111.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 89.0ms
# Speed: 0.0ms preprocess, 89.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 98.4ms
# Speed: 0.0ms preprocess, 98.4ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 97.5ms
# Speed: 8.5ms preprocess, 97.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 96.4ms
# Speed: 1.2ms preprocess, 96.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 98.3ms
# Speed: 2.4ms preprocess, 98.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 98.2ms
# Speed: 0.0ms preprocess, 98.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 1 truck, 98.7ms
# Speed: 0.0ms preprocess, 98.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 trains, 1 truck, 97.5ms
# Speed: 0.0ms preprocess, 97.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 1 truck, 99.4ms
# Speed: 0.0ms preprocess, 99.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 2 trucks, 98.7ms
# Speed: 8.2ms preprocess, 98.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 1 truck, 114.2ms
# Speed: 0.0ms preprocess, 114.2ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 89.7ms
# Speed: 7.6ms preprocess, 89.7ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 97.2ms
# Speed: 9.3ms preprocess, 97.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 107.1ms
# Speed: 0.0ms preprocess, 107.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 trains, 98.5ms
# Speed: 0.0ms preprocess, 98.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 train, 1 traffic light, 91.3ms
# Speed: 3.0ms preprocess, 91.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 airplane, 1 train, 91.7ms
# Speed: 3.4ms preprocess, 91.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 train, 1 truck, 95.3ms
# Speed: 2.6ms preprocess, 95.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 train, 103.4ms
# Speed: 1.9ms preprocess, 103.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 train, 106.2ms
# Speed: 0.0ms preprocess, 106.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 95.1ms
# Speed: 2.4ms preprocess, 95.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 97.7ms
# Speed: 0.0ms preprocess, 97.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 106.5ms
# Speed: 0.0ms preprocess, 106.5ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 107.2ms
# Speed: 0.0ms preprocess, 107.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 97.9ms
# Speed: 0.0ms preprocess, 97.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 train, 93.8ms
# Speed: 4.3ms preprocess, 93.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 105.6ms
# Speed: 0.0ms preprocess, 105.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 102.3ms
# Speed: 2.8ms preprocess, 102.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 105.3ms
# Speed: 5.4ms preprocess, 105.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 113.0ms
# Speed: 1.0ms preprocess, 113.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 truck, 88.3ms
# Speed: 2.9ms preprocess, 88.3ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trucks, 101.0ms
# Speed: 0.0ms preprocess, 101.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 105.8ms
# Speed: 0.9ms preprocess, 105.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 85.6ms
# Speed: 2.6ms preprocess, 85.6ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 93.8ms
# Speed: 0.0ms preprocess, 93.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 100.5ms
# Speed: 5.4ms preprocess, 100.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 110.4ms
# Speed: 0.0ms preprocess, 110.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 107.3ms
# Speed: 0.0ms preprocess, 107.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 108.5ms
# Speed: 0.0ms preprocess, 108.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 114.3ms
# Speed: 6.5ms preprocess, 114.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 97.0ms
# Speed: 4.5ms preprocess, 97.0ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 99.0ms
# Speed: 1.0ms preprocess, 99.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 airplanes, 98.3ms
# Speed: 0.0ms preprocess, 98.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 85.3ms
# Speed: 1.3ms preprocess, 85.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 106.8ms
# Speed: 6.2ms preprocess, 106.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 99.5ms
# Speed: 0.0ms preprocess, 99.5ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 122.5ms
# Speed: 0.0ms preprocess, 122.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 106.5ms
# Speed: 0.0ms preprocess, 106.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 90.1ms
# Speed: 0.0ms preprocess, 90.1ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 90.4ms
# Speed: 2.0ms preprocess, 90.4ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 107.5ms
# Speed: 0.0ms preprocess, 107.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 1 truck, 101.9ms
# Speed: 0.0ms preprocess, 101.9ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 164.4ms
# Speed: 8.5ms preprocess, 164.4ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 chair, 140.6ms
# Speed: 0.5ms preprocess, 140.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 traffic light, 103.4ms
# Speed: 0.0ms preprocess, 103.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 1 traffic light, 109.1ms
# Speed: 8.0ms preprocess, 109.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 101.0ms
# Speed: 5.3ms preprocess, 101.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 100.5ms
# Speed: 1.8ms preprocess, 100.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 truck, 93.2ms
# Speed: 5.5ms preprocess, 93.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 airplane, 107.4ms
# Speed: 0.0ms preprocess, 107.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 104.7ms
# Speed: 3.6ms preprocess, 104.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 107.0ms
# Speed: 6.3ms preprocess, 107.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 104.0ms
# Speed: 0.5ms preprocess, 104.0ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 113.0ms
# Speed: 0.0ms preprocess, 113.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 93.2ms
# Speed: 8.0ms preprocess, 93.2ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 98.0ms
# Speed: 8.4ms preprocess, 98.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 95.8ms
# Speed: 6.0ms preprocess, 95.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 truck, 1 traffic light, 91.7ms
# Speed: 5.1ms preprocess, 91.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 truck, 93.1ms
# Speed: 3.9ms preprocess, 93.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 98.1ms
# Speed: 0.0ms preprocess, 98.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 101.8ms
# Speed: 0.0ms preprocess, 101.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 truck, 100.3ms
# Speed: 0.0ms preprocess, 100.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 99.1ms
# Speed: 5.2ms preprocess, 99.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 98.7ms
# Speed: 0.0ms preprocess, 98.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 88.4ms
# Speed: 0.0ms preprocess, 88.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 97.7ms
# Speed: 0.0ms preprocess, 97.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 93.4ms
# Speed: 0.6ms preprocess, 93.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 85.9ms
# Speed: 1.8ms preprocess, 85.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 76.5ms
# Speed: 1.6ms preprocess, 76.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 83.2ms
# Speed: 2.7ms preprocess, 83.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 104.4ms
# Speed: 5.8ms preprocess, 104.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 101.6ms
# Speed: 3.8ms preprocess, 101.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 95.5ms
# Speed: 2.2ms preprocess, 95.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 103.6ms
# Speed: 1.3ms preprocess, 103.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 106.2ms
# Speed: 0.0ms preprocess, 106.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 108.2ms
# Speed: 0.0ms preprocess, 108.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 81.9ms
# Speed: 0.0ms preprocess, 81.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 75.2ms
# Speed: 3.4ms preprocess, 75.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 89.7ms
# Speed: 0.0ms preprocess, 89.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 98.1ms
# Speed: 0.0ms preprocess, 98.1ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
# Video frame is empty or video processing has been successfully completed.

# %%
import numpy as np
import cv2

def movingAverage(curve, radius): 
    window_size = 2 * radius + 1
    f = np.ones(window_size) / window_size 
    curve_pad = np.lib.pad(curve, (radius, radius), 'edge') 
    curve_smoothed = np.convolve(curve_pad, f, mode='same') 
    curve_smoothed = curve_smoothed[radius:-radius]
    return curve_smoothed 

def smooth(trajectory, smoothing_radius): 
    smoothed_trajectory = np.copy(trajectory) 
    for i in range(3):
        smoothed_trajectory[:,i] = movingAverage(trajectory[:,i], radius=smoothing_radius)
    return smoothed_trajectory

def fixBorder(frame):
    s = frame.shape
    T = cv2.getRotationMatrix2D((s[1]/2, s[0]/2), 0, 1.04)
    frame = cv2.warpAffine(frame, T, (s[1], s[0]))
    return frame

def stabilize_video(video_path, output_name, output_path=None, smoothing_radius=50):
    cap = cv2.VideoCapture(video_path) 
    n_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT)) 
    w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)) 
    h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    fourcc = cv2.VideoWriter_fourcc(*'MJPG')
    if output_path is None:
        output_path = f"{output_name}_stabilized.avi"
    else:
        output_path = f"{output_path}/{output_name}_stabilized.avi"
    out = cv2.VideoWriter(output_path, fourcc, fps, (2 * w, h))
    _, prev = cap.read() 
    prev_gray = cv2.cvtColor(prev, cv2.COLOR_BGR2GRAY) 
    transforms = np.zeros((n_frames-1, 3), np.float32) 

    for i in range(n_frames-2):
        prev_pts = cv2.goodFeaturesToTrack(prev_gray, maxCorners=200, qualityLevel=0.01, minDistance=30, blockSize=3)
        success, curr = cap.read() 
        if not success: 
            break 
        curr_gray = cv2.cvtColor(curr, cv2.COLOR_BGR2GRAY) 
        curr_pts, status, err = cv2.calcOpticalFlowPyrLK(prev_gray, curr_gray, prev_pts, None) 
        assert prev_pts.shape == curr_pts.shape 
        idx = np.where(status==1)[0]
        prev_pts = prev_pts[idx]
        curr_pts = curr_pts[idx]
        m = cv2.estimateAffine2D(prev_pts, curr_pts)[0]
        dx = m[0,2]
        dy = m[1,2]
        da = np.arctan2(m[1,0], m[0,0])
        transforms[i] = [dx, dy, da]
        prev_gray = curr_gray

    trajectory = np.cumsum(transforms, axis=0) 
    smoothed_trajectory = smooth(trajectory, smoothing_radius) 
    difference = smoothed_trajectory - trajectory
    transforms_smooth = transforms + difference
    cap.set(cv2.CAP_PROP_POS_FRAMES, 0) 

    for i in range(n_frames-2):
        success, frame = cap.read() 
        if not success:
            break
        dx = transforms_smooth[i,0]
        dy = transforms_smooth[i,1]
        da = transforms_smooth[i,2]
        m = np.zeros((2,3), np.float32)
        m[0,0] = np.cos(da)
        m[0,1] = -np.sin(da)
        m[1,0] = np.sin(da)
        m[1,1] = np.cos(da)
        m[0,2] = dx
        m[1,2] = dy
        frame_stabilized = cv2.warpAffine(frame, m, (w,h))
        frame_stabilized = fixBorder(frame_stabilized) 
        frame_out = cv2.hconcat([frame, frame_stabilized])
        if frame_out.shape[1] > 1920: 
            frame_out = cv2.resize(frame_out, (frame_out.shape[1]//2, frame_out.shape[0]//2));
        out.write(frame_out)

    cap.release()
    out.release()
    cv2.destroyAllWindows()
    
    return output_path

if __name__ == "__main__":
    # Example usage:
    stabilized_video_path = stabilize_video("stablize.mp4", "stabilized_video")
    print("Stabilized video saved at:", stabilized_video_path)
# Out:
# Stabilized video saved at: stabilized_video_stabilized.avi

# %%
import numpy as np
import cv2

def movingAverage(curve, radius): 
    window_size = 2 * radius + 1
    f = np.ones(window_size) / window_size 
    curve_pad = np.lib.pad(curve, (radius, radius), 'edge') 
    curve_smoothed = np.convolve(curve_pad, f, mode='same') 
    curve_smoothed = curve_smoothed[radius:-radius]
    return curve_smoothed 

def smooth(trajectory, smoothing_radius): 
    smoothed_trajectory = np.copy(trajectory) 
    for i in range(3):
        smoothed_trajectory[:,i] = movingAverage(trajectory[:,i], radius=smoothing_radius)
    return smoothed_trajectory

def fixBorder(frame):
    s = frame.shape
    T = cv2.getRotationMatrix2D((s[1]/2, s[0]/2), 0, 1.04)
    frame = cv2.warpAffine(frame, T, (s[1], s[0]))
    return frame

def stabilize_video(video_path, output_path, smoothing_radius=50):
    cap = cv2.VideoCapture(video_path) 
    n_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT)) 
    w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)) 
    h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    fourcc = cv2.VideoWriter_fourcc(*'MJPG')
    out = cv2.VideoWriter(output_path, fourcc, fps, (2 * w, h))
    _, prev = cap.read() 
    prev_gray = cv2.cvtColor(prev, cv2.COLOR_BGR2GRAY) 
    transforms = np.zeros((n_frames-1, 3), np.float32) 

    for i in range(n_frames-2):
        prev_pts = cv2.goodFeaturesToTrack(prev_gray, maxCorners=200, qualityLevel=0.01, minDistance=30, blockSize=3)
        success, curr = cap.read() 
        if not success: 
            break 
        curr_gray = cv2.cvtColor(curr, cv2.COLOR_BGR2GRAY) 
        curr_pts, status, err = cv2.calcOpticalFlowPyrLK(prev_gray, curr_gray, prev_pts, None) 
        assert prev_pts.shape == curr_pts.shape 
        idx = np.where(status==1)[0]
        prev_pts = prev_pts[idx]
        curr_pts = curr_pts[idx]
        m = cv2.estimateAffinePartial2D(prev_pts, curr_pts)[0]
        dx = m[0,2]
        dy = m[1,2]
        da = np.arctan2(m[1,0], m[0,0])
        transforms[i] = [dx, dy, da]
        prev_gray = curr_gray

    trajectory = np.cumsum(transforms, axis=0) 
    smoothed_trajectory = smooth(trajectory, smoothing_radius) 
    difference = smoothed_trajectory - trajectory
    transforms_smooth = transforms + difference
    cap.set(cv2.CAP_PROP_POS_FRAMES, 0) 

    for i in range(n_frames-2):
        success, frame = cap.read() 
        if not success:
            break
        dx = transforms_smooth[i,0]
        dy = transforms_smooth[i,1]
        da = transforms_smooth[i,2]
        m = np.zeros((2,3), np.float32)
        m[0,0] = np.cos(da)
        m[0,1] = -np.sin(da)
        m[1,0] = np.sin(da)
        m[1,1] = np.cos(da)
        m[0,2] = dx
        m[1,2] = dy
        frame_stabilized = cv2.warpAffine(frame, m, (w,h))
        frame_stabilized = fixBorder(frame_stabilized) 
        frame_out = cv2.hconcat([frame, frame_stabilized])
        if frame_out.shape[1] > 1920: 
            frame_out = cv2.resize(frame_out, (frame_out.shape[1]//2, frame_out.shape[0]//2));
        out.write(frame_out)

    cap.release()
    out.release()
    cv2.destroyAllWindows()
    
    return output_path

# Example usage:
stabilized_video_path = stabilize_video("stablize.mp4", "stabilized_video_out.avi")
print("Stabilized video saved at:", stabilized_video_path)
# Out:
# Stabilized video saved at: stabilized_video_out.avi
